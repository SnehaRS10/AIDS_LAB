# %% [markdown]
# <a href="https://colab.research.google.com/github/SnehaRS10/AIDS_LAB/blob/main/AI%26DS_Exp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/world-happiness-report-2021.csv')

# %%
data = data.drop(columns=['Ladder score in Dystopia'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-905dc3a7cbab> in <cell line: 1>()
# ----> 1 data = data.drop(columns=['Ladder score in Dystopia'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
data.head(5)
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
pearsoncorr = data.corr(method='pearson')
pearsoncorr
# Out:
# <ipython-input-16-65f6b807ee44>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   pearsoncorr = data.corr(method='pearson')
#                                             Ladder score  \
# Ladder score                                    1.000000
# Standard error of ladder score                 -0.470787
# upperwhisker                                    0.999347
# lowerwhisker                                    0.999396
# Logged GDP per capita                           0.789760
# Social support                                  0.756888
# Healthy life expectancy                         0.768099
# Freedom to make life choices                    0.607753
# Generosity                                     -0.017799
# Perceptions of corruption                      -0.421140
# ...

# %%
sns.heatmap(data.corr(method='pearson'))
# Out:
# <ipython-input-17-167a523d5d82>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr(method='pearson'))
# <Axes: >

# %%
data.corr(numeric_only=True, method='spearman')
# Out:
#                                             Ladder score  \
# Ladder score                                    1.000000
# Standard error of ladder score                 -0.556192
# upperwhisker                                    0.999085
# lowerwhisker                                    0.999195
# Logged GDP per capita                           0.809407
# Social support                                  0.797993
# Healthy life expectancy                         0.796862
# Freedom to make life choices                    0.607086
# Generosity                                     -0.007643
# Perceptions of corruption                      -0.300833
# Explained by: Log GDP per capita                0.809452
# Explained by: Social support                    0.798312
# Explained by: Healthy life expectancy           0.796232
# Explained by: Freedom to make life choices      0.607523
# Explained by: Generosity                       -0.008093
# ...
